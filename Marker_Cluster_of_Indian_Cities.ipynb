# %% [markdown]
# <a href="https://colab.research.google.com/github/Bha5vya/Google-Earth-Engine-Basic-Code/blob/Programs-on-Google-Collab/Marker_Cluster_of_Indian_Cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install leafmap
import leafmap

# %%
m = leafmap.Map()

location="https://raw.githubusercontent.com/Vynex/indian-cities-geodata/refs/heads/main/src/cities.csv"
m.add_points_from_xy(location, x="longitude", y="latitude", layer_name="Indian Cities")

m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
